# %% [markdown]
# <a id="intro"></a>
# <h2>
#       <font color = purple >
#             <span style='font-family:Georgia'>
#             1. Introduction:
#             </span>
#         </font>
# </h2>

# %% [markdown]
# <h3 >
#       <font color = black >
#             <span style='font-family:Georgia'>
#             Introduction:
#             </span>
#         </font>
# </h3>
# <p>
#     <span style='font-family:Georgia'>
# The film industry has evolved significantly in recent years, driven by the rise of digital platforms and the increasing influence of user-generated content. Movie rating sites have become essential tools for audiences seeking recommendations and for studios aiming to understand viewer preferences. These platforms aggregate a vast amount of data, including user ratings, reviews, and engagement metrics, creating a rich repository for analysis.
#
# This exploratory data analysis project aims to delve into the intricacies of data collected from movie rating sites. By examining patterns, trends, and user behaviors, we seek to uncover insights that can inform business strategies, enhance user experiences, and predict future movie successes. Understanding the dynamics at play in audience ratings and feedback will empower stakeholders to make data-driven decisions, ultimately benefiting consumers and the industry alike.
#     </span>
# </p>
# <hr>
# <h3>
#     <font color = black >
#         <span style='font-family:Georgia'>
#             Business Understanding:
#             </span>
#         </font>
# </h3>
# <p>
#     <span style='font-family:Georgia'>
# In today's digital age, movie rating sites play a crucial role in influencing consumer choices and shaping the entertainment industry. These platforms aggregate user reviews, ratings, and other metrics, offering valuable insights into audience preferences and trends. By analyzing data from these sites, businesses can better understand viewer behavior, enhance user engagement, and improve content recommendations.
#     </span>
#     </p>
#   <h3>
#       <font color = black >
#             <span style='font-family:Georgia'>
#             Business Objective:
#             </span>
#         </font>
# </h3>
# <p>
#     <span style='font-family:Georgia'>
#         <li><b>Identify Key Trends:</b> Analyze historical rating data to uncover patterns in audience preferences across genres, actors, and directors.</li>
#
#
# <li><b>Enhance User Experience:</b> Evaluate user interaction metrics to improve site usability and increase user retention.</li>
#
#
# <li><b>Predict Future Success:</b> Develop models to forecast a movie’s potential success based on early ratings and trends, aiding producers and marketers in decision-making.</li>
#
#
# <li><b>Segment Audience:</b> Categorize users based on their rating habits and preferences to tailor marketing strategies and content offerings.</li>
#
#
# <li><b>Evaluate Sentiment:</b> Conduct sentiment analysis on user reviews to gauge public perception and inform marketing campaigns.</li>
#
#
#
# By achieving these objectives, the project aims to provide actionable insights that enhance the operational strategies of movie rating sites, ultimately driving engagement and profitability.
#     </span>
# </p>

# %% [markdown]
# <a id="libraries"></a>
# <h2>
#       <font color = purple >
#             <span style='font-family:Georgia'>
#             2. Getting Jupyter Ready:
#             </span>
#         </font>
# </h2>

# %% [markdown]
# <h3 name='libraries'>
#       <font color = black >
#             <span style='font-family:Georgia'>
#             2.1 Import Python Libraries:
#             </span>
#         </font>
# </h3>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <a id="import"></a>
# <h2>
#       <font color = purple >
#             <span style='font-family:Georgia'>
#             3. Reading & Understanding the data
#             </span>
#         </font>
# </h2>

# %% [markdown]
# <a id="input"></a>
# <h3 name='libraries'>
#       <font color = black >
#             <span style='font-family:Georgia'>
#             3.1 Importing the input files
#             </span>
#         </font>
# </h3>

# %%
fandango = pd.read_csv("fandango_scrape.csv")

# %% [markdown]
# <a id="input"></a>
# <h3 name='libraries'>
#       <font color = black >
#             <span style='font-family:Georgia'>
#             3.2 Exploring the DataFrame Properties and Head
#             </span>
#         </font>
# </h3>

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1        Jurassic World (2015)    4.5     4.5  34390
# 2       American Sniper (2015)    5.0     4.8  34085
# 3             Furious 7 (2015)    5.0     4.8  33538
# 4            Inside Out (2015)    4.5     4.5  15749

# %%
fandango.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504 entries, 0 to 503
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   FILM    504 non-null    object
#  1   STARS   504 non-null    float64
#  2   RATING  504 non-null    float64
#  3   VOTES   504 non-null    int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.9+ KB

# %%
fandango.describe()
# Out:
#             STARS      RATING         VOTES
# count  504.000000  504.000000    504.000000
# mean     3.558532    3.375794   1147.863095
# std      1.563133    1.491223   3830.583136
# min      0.000000    0.000000      0.000000
# 25%      3.500000    3.100000      3.000000
# 50%      4.000000    3.800000     18.500000
# 75%      4.500000    4.300000    189.750000
# max      5.000000    5.000000  34846.000000

# %% [markdown]
# <a id="input"></a>
# <h3 name='libraries'>
#       <font color = black >
#             <span style='font-family:Georgia'>
#             3.3 Creating a scatterplot to show the relationship between rating and votes
#             </span>
#         </font>
# </h3>

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.scatterplot(data=fandango,x='RATING',y='VOTES',color='purple')
# Out:
# <Axes: xlabel='RATING', ylabel='VOTES'>

# %% [markdown]
# <a id="input"></a>
# <h3 name='libraries'>
#       <font color = black >
#             <span style='font-family:Georgia'>
#             3.4 Calculating the correlation between the columns
#             </span>
#         </font>
# </h3>

# %%
df=fandango.drop('FILM',axis=1)

# %%
df.corr()
# Out:
#            STARS    RATING     VOTES
# STARS   1.000000  0.994696  0.164218
# RATING  0.994696  1.000000  0.163764
# VOTES   0.164218  0.163764  1.000000

# %%
YEAR=fandango['FILM'].str.split('(').str[-1]

# %%
fandango['YEAR']=YEAR

# %%
fandango.head()
# Out:
#                           FILM  STARS  RATING  VOTES   YEAR
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015)
# 1        Jurassic World (2015)    4.5     4.5  34390  2015)
# 2       American Sniper (2015)    5.0     4.8  34085  2015)
# 3             Furious 7 (2015)    5.0     4.8  33538  2015)
# 4            Inside Out (2015)    4.5     4.5  15749  2015)

# %%
fandango['YEAR'].value_counts()
# Out:
# YEAR
# 2015)    478
# 2014)     23
# 2016)      1
# 1964)      1
# 2012)      1
# Name: count, dtype: int64

# %% [markdown]
# <a id="input"></a>
# <h3 name='libraries'>
#       <font color = black >
#             <span style='font-family:Georgia'>
#             3.5 Visualizing the count of movies per year with a plot
#             </span>
#         </font>
# </h3>

# %%
sns.countplot(data=fandango,x='YEAR')
# Out:
# <Axes: xlabel='YEAR', ylabel='count'>

# %% [markdown]
# **10 movies with the highest number of votes**

# %%
fandango.nlargest(10,'VOTES')
# Out:
#                                                FILM  STARS  RATING  VOTES  \
# 0                       Fifty Shades of Grey (2015)    4.0     3.9  34846
# 1                             Jurassic World (2015)    4.5     4.5  34390
# 2                            American Sniper (2015)    5.0     4.8  34085
# 3                                  Furious 7 (2015)    5.0     4.8  33538
# 4                                 Inside Out (2015)    4.5     4.5  15749
# 5  The Hobbit: The Battle of the Five Armies (2014)    4.5     4.3  15337
# 6               Kingsman: The Secret Service (2015)    4.5     4.2  15205
# 7                                    Minions (2015)    4.0     4.0  14998
# 8                    Avengers: Age of Ultron (2015)    5.0     4.5  14846
# 9                             Into the Woods (2014)    3.5     3.4  13055
#
#     YEAR
# 0  2015)
# 1  2015)
# 2  2015)
# 3  2015)
# 4  2015)
# 5  2014)
# 6  2015)
# 7  2015)
# 8  2015)
# 9  2014)

# %%
len(fandango[fandango['VOTES']==0])
# Out:
# 69

# %%
fandango1=fandango[fandango['VOTES']!=0]

# %%
fandango1.head()
# Out:
#                           FILM  STARS  RATING  VOTES   YEAR
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015)
# 1        Jurassic World (2015)    4.5     4.5  34390  2015)
# 2       American Sniper (2015)    5.0     4.8  34085  2015)
# 3             Furious 7 (2015)    5.0     4.8  33538  2015)
# 4            Inside Out (2015)    4.5     4.5  15749  2015)

# %%
len(fandango)
# Out:
# 504

# %%
len(fandango1)
# Out:
# 435

# %% [markdown]
# <a id="input"></a>
# <h3 name='libraries'>
#       <font color = black >
#             <span style='font-family:Georgia'>
#             3.6 Creating a KDE plot (or multiple kdeplots) that displays the distribution of ratings that are displayed (STARS) versus what the true rating was from votes (RATING)
#             </span>
#         </font>
# </h3>

# %%
plt.figure(figsize=(8,4),dpi=200)
sns.kdeplot(data=fandango1,x='RATING',clip=[0,5],shade=True,label='True Rating')
sns.kdeplot(data=fandango1,x='STARS',clip=[0,5],shade=True,label='Stars Displayed')
plt.legend(loc=(1.05,0.5))
# Out:
# <ipython-input-36-3ca2e19df7e2>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=fandango1,x='RATING',clip=[0,5],shade=True,label='True Rating')
# <ipython-input-36-3ca2e19df7e2>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=fandango1,x='STARS',clip=[0,5],shade=True,label='Stars Displayed')

# %% [markdown]
# **Creating a new column of the difference between STARS displayed versus true RATING**

# %%
fandango1['STARS_DIFF']=np.round(fandango1['STARS']-fandango1['RATING'],1)
# Out:
# <ipython-input-37-c79701485adf>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fandango1['STARS_DIFF']=np.round(fandango1['STARS']-fandango1['RATING'],1)

# %%
fandango1.head()
# Out:
#                           FILM  STARS  RATING  VOTES   YEAR  STARS_DIFF
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846  2015)         0.1
# 1        Jurassic World (2015)    4.5     4.5  34390  2015)         0.0
# 2       American Sniper (2015)    5.0     4.8  34085  2015)         0.2
# 3             Furious 7 (2015)    5.0     4.8  33538  2015)         0.2
# 4            Inside Out (2015)    4.5     4.5  15749  2015)         0.0

# %% [markdown]
# <a id="input"></a>
# <h3 name='libraries'>
#       <font color = black >
#             <span style='font-family:Georgia'>
#             3.7 Creating a count plot to display the number of times a certain difference occurs
#             </span>
#         </font>
# </h3>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(data=fandango1,x='STARS_DIFF',palette='magma')
# Out:
# <ipython-input-45-ac3ad450faf7>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=fandango1,x='STARS_DIFF',palette='magma')
# <Axes: xlabel='STARS_DIFF', ylabel='count'>

# %%
fandango1[fandango1['STARS_DIFF']==1.0]
# Out:
#                  FILM  STARS  RATING  VOTES   YEAR  STARS_DIFF
# 381  Turbo Kid (2015)    5.0     4.0      2  2015)         1.0

# %% [markdown]
# ### Comparison of Fandango Ratings to Other Sites

# %%
all_sites = pd.read_csv("all_sites_scores.csv")

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count
# 0                271107
# 1                 65709
# 2                103660
# 3                  3136
# ...

# %%
all_sites.describe()
# Out:
#        RottenTomatoes  RottenTomatoes_User  Metacritic  Metacritic_User  \
# count      146.000000           146.000000  146.000000       146.000000
# mean        60.849315            63.876712   58.808219         6.519178
# std         30.168799            20.024430   19.517389         1.510712
# min          5.000000            20.000000   13.000000         2.400000
# 25%         31.250000            50.000000   43.500000         5.700000
# 50%         63.500000            66.500000   59.000000         6.850000
# 75%         89.000000            81.000000   75.000000         7.500000
# max        100.000000            94.000000   94.000000         9.600000
#
#              IMDB  Metacritic_user_vote_count  IMDB_user_vote_count
# count  146.000000                  146.000000            146.000000
# mean     6.736986                  185.705479          42846.205479
# std      0.958736                  316.606515          67406.509171
# ...

# %%
all_sites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 8 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        146 non-null    object
#  1   RottenTomatoes              146 non-null    int64
#  2   RottenTomatoes_User         146 non-null    int64
#  3   Metacritic                  146 non-null    int64
#  4   Metacritic_User             146 non-null    float64
#  5   IMDB                        146 non-null    float64
#  6   Metacritic_user_vote_count  146 non-null    int64
#  7   IMDB_user_vote_count        146 non-null    int64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 9.2+ KB

# %% [markdown]
# ### Rotten Tomatoes
#
# **Creating a scatterplot exploring the relationship between RT Critic reviews and RT User reviews**

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(data=all_sites,x='RottenTomatoes',y='RottenTomatoes_User')
# Out:
# <Axes: xlabel='RottenTomatoes', ylabel='RottenTomatoes_User'>

# %%
all_sites['RT_DIFF']=all_sites['RottenTomatoes']-all_sites['RottenTomatoes_User']

# %%
all_sites.head()
# Out:
#                              FILM  RottenTomatoes  RottenTomatoes_User  \
# 0  Avengers: Age of Ultron (2015)              74                   86
# 1               Cinderella (2015)              85                   80
# 2                  Ant-Man (2015)              80                   90
# 3          Do You Believe? (2015)              18                   84
# 4   Hot Tub Time Machine 2 (2015)              14                   28
#
#    Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 0          66              7.1   7.8                        1330
# 1          67              7.5   7.1                         249
# 2          64              8.1   7.8                         627
# 3          22              4.7   5.4                          31
# 4          29              3.4   5.1                          88
#
#    IMDB_user_vote_count  RT_DIFF
# 0                271107      -12
# 1                 65709        5
# 2                103660      -10
# ...

# %%
(sum(abs(all_sites['RT_DIFF'])))/len(all_sites)
# Out:
# 15.095890410958905

# %%
plt.figure(figsize=(10,4))
sns.histplot(data=all_sites,x='RT_DIFF',bins=25,kde=True)
plt.title('RT Critics Score minus RT User Score')
# Out:
# Text(0.5, 1.0, 'RT Critics Score minus RT User Score')

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.histplot(data=all_sites,x=abs(all_sites['RT_DIFF']),bins=25,kde=True)
plt.title('Abs Difference between RT Critics Score and RT Users Score')
# Out:
# Text(0.5, 1.0, 'Abs Difference between RT Critics Score and RT Users Score')

# %% [markdown]
# **Top 5 movies users rated higher than critics on average**

# %%
all_sites.nsmallest(5,'RT_DIFF')[['FILM','RT_DIFF']]
# Out:
#                           FILM  RT_DIFF
# 3       Do You Believe? (2015)      -66
# 85           Little Boy (2015)      -61
# 105    Hitman: Agent 47 (2015)      -42
# 134    The Longest Ride (2015)      -42
# 125  The Wedding Ringer (2015)      -39

# %% [markdown]
# **Top 5 movies critics scores higher than users on average**

# %%
all_sites.nlargest(5,'RT_DIFF')[['FILM','RT_DIFF']]
# Out:
#                                  FILM  RT_DIFF
# 69                  Mr. Turner (2014)       42
# 112                 It Follows (2015)       31
# 115          While We're Young (2015)       31
# 37               Welcome to Me (2015)       24
# 40   I'll See You In My Dreams (2015)       24

# %% [markdown]
# ### Meta Critic
#
# **Displaying a scatterplot of the Metacritic Rating versus the Metacritic User rating**

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(data=all_sites,x='Metacritic',y='Metacritic_User')
# Out:
# <Axes: xlabel='Metacritic', ylabel='Metacritic_User'>

# %% [markdown]
# ### IMDB
#
# **Creating a scatterplot for the relationship between vote counts on MetaCritic versus vote counts on IMDB**

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(data=all_sites,x='Metacritic_user_vote_count',y='IMDB_user_vote_count')
# Out:
# <Axes: xlabel='Metacritic_user_vote_count', ylabel='IMDB_user_vote_count'>

# %%
all_sites.nlargest(1,'IMDB_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 14  The Imitation Game (2014)              90                   92
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 14          73              8.2   8.1                         566
#
#     IMDB_user_vote_count
# 14                334164

# %%
all_sites.nlargest(1,'Metacritic_user_vote_count')
# Out:
#                          FILM  RottenTomatoes  RottenTomatoes_User  \
# 88  Mad Max: Fury Road (2015)              97                   88
#
#     Metacritic  Metacritic_User  IMDB  Metacritic_user_vote_count  \
# 88          89              8.7   8.3                        2375
#
#     IMDB_user_vote_count
# 88                292023

# %% [markdown]
# ### Fandago Scores vs. All Sites
#
# **We only want to compare movies that are in both DataFrames, so we do an inner merge to merge together both DataFrames based on the FILM columns**

# %%
df=pd.merge(fandango,all_sites,how='inner',on='FILM')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   FILM                        145 non-null    object
#  1   STARS                       145 non-null    float64
#  2   RATING                      145 non-null    float64
#  3   VOTES                       145 non-null    int64
#  4   RottenTomatoes              145 non-null    int64
#  5   RottenTomatoes_User         145 non-null    int64
#  6   Metacritic                  145 non-null    int64
#  7   Metacritic_User             145 non-null    float64
#  8   IMDB                        145 non-null    float64
#  9   Metacritic_user_vote_count  145 non-null    int64
#  10  IMDB_user_vote_count        145 non-null    int64
#  11  RT_DIFF                     145 non-null    int64
# dtypes: float64(4), int64(7), object(1)
# memory usage: 13.7+ KB

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846              25
# 1        Jurassic World (2015)    4.5     4.5  34390              71
# 2       American Sniper (2015)    5.0     4.8  34085              72
# 3             Furious 7 (2015)    5.0     4.8  33538              81
# 4            Inside Out (2015)    4.5     4.5  15749              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  RT_DIFF
# 0                         778                179506      -17
# 1                        1281                241807      -10
# ...

# %% [markdown]
# **Creating new normalized columns for all ratings so they match up within the 0-5 star range shown on Fandango**

# %%
df['RT_Norm']=np.round(df['RottenTomatoes']/20,1)

# %%
df['RTU_Norm']=np.round(df['RottenTomatoes_User']/20,1)

# %%
df['Meta_Norm']=np.round(df['Metacritic']/20,1)

# %%
df['MetaU_Norm']=np.round(df['Metacritic_User']/2,1)

# %%
df['IMDB_Norm']=np.round(df['IMDB']/2,1)

# %%
df.head()
# Out:
#                           FILM  STARS  RATING  VOTES  RottenTomatoes  \
# 0  Fifty Shades of Grey (2015)    4.0     3.9  34846              25
# 1        Jurassic World (2015)    4.5     4.5  34390              71
# 2       American Sniper (2015)    5.0     4.8  34085              72
# 3             Furious 7 (2015)    5.0     4.8  33538              81
# 4            Inside Out (2015)    4.5     4.5  15749              98
#
#    RottenTomatoes_User  Metacritic  Metacritic_User  IMDB  \
# 0                   42          46              3.2   4.2
# 1                   81          59              7.0   7.3
# 2                   85          72              6.6   7.4
# 3                   84          67              6.8   7.4
# 4                   90          94              8.9   8.6
#
#    Metacritic_user_vote_count  IMDB_user_vote_count  RT_DIFF  RT_Norm  \
# 0                         778                179506      -17      1.2
# ...

# %%
norm_scores=df[['STARS','RATING','RT_Norm','RTU_Norm','Meta_Norm','MetaU_Norm','IMDB_Norm']]

# %%
norm_scores.head()
# Out:
#    STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  MetaU_Norm  IMDB_Norm
# 0    4.0     3.9      1.2       2.1        2.3         1.6        2.1
# 1    4.5     4.5      3.6       4.0        3.0         3.5        3.6
# 2    5.0     4.8      3.6       4.2        3.6         3.3        3.7
# 3    5.0     4.8      4.0       4.2        3.4         3.4        3.7
# 4    4.5     4.5      4.9       4.5        4.7         4.4        4.3

# %% [markdown]
# ### Comparing Distribution of Scores Across Sites

# %%
def move_legend(ax, new_loc, **kws):
    old_legend = ax.legend_
    handles = old_legend.legendHandles
    labels = [t.get_text() for t in old_legend.get_texts()]
    title = old_legend.get_title().get_text()
    ax.legend(handles, labels, loc=new_loc, title=title, **kws)

# %%
fig,ax=plt.subplots(figsize=(10,4),dpi=150)
sns.kdeplot(data=norm_scores,clip=[0,5],shade=True,ax=ax,palette='Set1')
#plt.legend(loc='upper left')
move_legend(ax, "upper left")
# Out:
# <ipython-input-40-4833033285ee>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=norm_scores,clip=[0,5],shade=True,ax=ax,palette='Set1')
# <ipython-input-38-3ba61b48a3a0>:3: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = old_legend.legendHandles

# %% [markdown]
# **Clearly Fandango has an uneven distribution. We can also see that RT critics have the most uniform distribution. Let's directly compare these two.**
#
# **Creating a KDE plot that compare the distribution of RT critic ratings against the STARS displayed by Fandango**

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.kdeplot(data=norm_scores,x='RT_Norm',shade=True,label='RT_Norm',clip=[0,5])
sns.kdeplot(data=norm_scores,x='STARS',shade=True,label='STARS',clip=[0,5])
plt.legend(loc='upper left')
# Out:
# <ipython-input-48-9072dd3912c1>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=norm_scores,x='RT_Norm',shade=True,label='RT_Norm',clip=[0,5])
# <ipython-input-48-9072dd3912c1>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=norm_scores,x='STARS',shade=True,label='STARS',clip=[0,5])

# %%
fig, ax = plt.subplots(figsize=(15,6),dpi=150)
sns.kdeplot(data=norm_scores[['RT_Norm','STARS']],clip=[0,5],shade=True,palette='Set1',ax=ax)
move_legend(ax, "upper left")
# Out:
# <ipython-input-47-420a099c761d>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=norm_scores[['RT_Norm','STARS']],clip=[0,5],shade=True,palette='Set1',ax=ax)
# <ipython-input-38-3ba61b48a3a0>:3: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   handles = old_legend.legendHandles

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.histplot(data=norm_scores,bins=50)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# **Creating a clustermap visualization of all normalized scores. Noting the differences in ratings, highly rated movies should be clustered together versus poorly rated movies**

# %%
sns.clustermap(data=norm_scores,col_cluster=False,cmap='magma')

# %% [markdown]
# **Clearly Fandango is rating movies much higher than other sites, especially considering that it is then displaying a rounded up version of the rating.**

# %%
norm_scores_film=df[['STARS','RATING','RT_Norm','RTU_Norm','Meta_Norm','MetaU_Norm','IMDB_Norm','FILM']]

# %%
norm_scores_film.nsmallest(10,'RT_Norm')
# Out:
#     STARS  RATING  RT_Norm  RTU_Norm  Meta_Norm  MetaU_Norm  IMDB_Norm  \
# 49    3.5     3.5      0.2       1.8        0.6         1.2        2.2
# 25    4.5     4.1      0.4       2.3        1.3         2.3        3.0
# 28    3.0     2.7      0.4       1.0        1.4         1.2        2.0
# 54    4.0     3.7      0.4       1.8        1.6         1.8        2.4
# 84    4.0     3.9      0.4       2.4        1.4         1.6        3.0
# 50    4.0     3.6      0.5       1.8        1.5         2.8        2.3
# 77    3.5     3.2      0.6       1.8        1.5         2.0        2.8
# 78    3.5     3.2      0.6       1.5        1.4         1.6        2.8
# 83    3.5     3.3      0.6       1.7        1.6         2.5        2.8
# 87    3.5     3.2      0.6       1.4        1.6         1.9        2.7
#
#                              FILM
# 49  Paul Blart: Mall Cop 2 (2015)
# 25                 Taken 3 (2015)
# 28          Fantastic Four (2015)
# 54             Hot Pursuit (2015)
# ...

# %% [markdown]
# **Visualizing the distribution of ratings across all sites for the top 10 worst movies**

# %%
plt.figure(figsize=(10,4),dpi=150)
sns.kdeplot(data=norm_scores_film.nsmallest(10,'RT_Norm'),shade=True,clip=[0,5])
# Out:
# <ipython-input-58-e85021de81fa>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=norm_scores_film.nsmallest(10,'RT_Norm'),shade=True,clip=[0,5])
# <Axes: ylabel='Density'>

# %%
norm_scores_film.iloc[25]
# Out:
# STARS                    4.5
# RATING                   4.1
# RT_Norm                  0.4
# RTU_Norm                 2.3
# Meta_Norm                1.3
# MetaU_Norm               2.3
# IMDB_Norm                3.0
# FILM          Taken 3 (2015)
# Name: 25, dtype: object
